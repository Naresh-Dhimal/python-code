# %% [markdown]
# # Assignment3:

# %% [markdown]
# # Assignment 3.1:
# ![image.png](attachment:2e0815e1-3606-49a2-9615-73dc92e51ac6.png)

# %%
first_number = int(input('Enter a first number: '))
second_number = int(input('Enter a second number: '))
add = first_number + second_number
print(f'The sum of {first_number} and {second_number} is {add}.')
# Out:
# Enter a first number:  2
# Enter a second number:  44
# The sum of 2 and 44 is 46.

# %% [markdown]
# # Assignment 3.2:
# ![image.png](attachment:2de24d8b-6ed2-451a-b54b-623b9f30a47e.png)

# %%
number = int(input('Enter a number: '))
if number % 2 == 0:
    print("Even")
else:
    print('Odd')
# Out:
# Enter a number:  12
# Even

# %% [markdown]
# # Assignment 3.3:
# ![image.png](attachment:881d6b27-24f4-4a3b-88d5-5b46bd3d6577.png)

# %%
number = int(input('Enter a number: '))
if number == 10:
    print('number is 10')
else: 
    print('number is not 10.')
# Out:
# Enter a number:  13
# number is not 10.

# %% [markdown]
# # Assignment 3.4:
# ![image.png](attachment:781b9ec4-6324-42fc-a189-7f32036923a6.png)

# %%
number = int(input('Enter a number:'))
if number > 0:
    print("positive")
else:
    print('Negative')
# Out:
# Enter a number: -12
# Negative

# %% [markdown]
# # Assignment 3.5:
# ![image.png](attachment:41e27db9-ef2e-4051-8102-246e5f3ed1f5.png)

# %%
number = int(input('Enter a number: '))
if number % 5 == 0:
    print('Hello')
else:
    print('Bye')
# Out:
# Enter a number:  25
# Hello

# %% [markdown]
# # Assignment 3.6:
# ![image.png](attachment:bc35736b-d3e0-4297-8821-77cd5747b8a9.png)

# %%
age = int(input('Enter your age: '))
if age >= 18:
    print("You are eligible for voting.")
else:
    print('You are not eligible for voting.')
# Out:
# Enter your age:  18
# You are eligible for voting.

# %% [markdown]
# # Assignment 3.7:
# ![image.png](attachment:1adf94eb-e8ff-401a-8ae2-c972680cbede.png)

# %%
number = int(input('Enter a number: '))
last_number = number % 10
if last_number % 3 == 0:
    print(f'The last digit of {number} is {last_number} and it is divisible by 3.')
else:
    print(f'The last digit of {number} is {last_number} and it is not divisible by 3.')
# Out:
# Enter a number:  15
# The last digit of 15 is 5 and it is not divisible by 3.

# %% [markdown]
# # Assignment 3.8:
# ![image.png](attachment:1731f1a9-7c40-45ea-8d34-db34f3390bc8.png)

# %%
number = int(input('Enter a number: '))
if number == 0:
    print('Zero')
elif number > 0:
    print('Positive')
else:
    print('Negative')
# Out:
# Enter a number:  -2
# Negative

# %% [markdown]
# # Assignment 3.9:
# ![image.png](attachment:9cce29fa-6d9c-4c38-a2f0-052e0275febb.png)

# %%
number = int(input('Enter a number: '))
if number == 0:
    print('Zero')
elif number > 0:
    if number % 2 == 0:
        print('Number is positive and even.')
    else:
        print('Number is positive and odd.')
else:
    print('Negative')
# Out:
# Enter a number:  -12
# Negative

# %% [markdown]
# # Assignment 3.10:
# ![image.png](attachment:7aaab4bd-a1db-44e3-9390-db848007d347.png)

# %%
weight = float(input('Enter a weight(in kg): '))
height = float(input('Enter a height(in cm): '))
bmi = weight / (height /100) ** 2
print(f'Your body mass index is {bmi}')
if bmi < 18.5:
    print('You are underweight.')
elif bmi >= 18.5 and bmi <= 24.9:
    print('You are normal weight.')
elif bmi > 24.9 and bmi < 30:
    print('You are Overweight.')
else:
    print('You are obesity.')
